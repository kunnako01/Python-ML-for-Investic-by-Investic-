# %%
import pandas_datareader as web

# %%
start = '2016-01-01'
end = '2021-01-01'

# %%
tsla = web.get_data_yahoo('TSLA', start=start, end=end)

# %%
tsla
# Out:
#                   High         Low  ...      Volume   Adj Close
# Date                                ...
# 2016-01-04   46.276001   43.799999  ...  34135500.0   44.681999
# 2016-01-05   45.377998   44.000000  ...  15934000.0   44.686001
# 2016-01-06   44.009998   43.195999  ...  18895500.0   43.807999
# 2016-01-07   43.688000   42.734001  ...  17771500.0   43.130001
# 2016-01-08   44.088001   42.153999  ...  18140500.0   42.200001
# ...                ...         ...  ...         ...         ...
# 2020-12-24  666.090027  641.000000  ...  22865600.0  661.770020
# 2020-12-28  681.400024  660.799988  ...  32278600.0  663.690002
# 2020-12-29  669.900024  655.000000  ...  22910800.0  665.989990
# 2020-12-30  696.599976  668.359985  ...  42846000.0  694.780029
# 2020-12-31  718.719971  691.119995  ...  49649900.0  705.669983
#
# [1259 rows x 6 columns]

# %% [markdown]
# ### Tips

# %% [markdown]
# ข้อดีที่ชอบมากเลยคือสามารถเลือกความถี่ได้ด้วย .asfreq() ส่วนในวงเล็บก็เลือกได้เลยจะเอาความถี่แบบไหน W = Weekly, M = Monthly และสามารถเลือกได้ด้วยว่าจะเอาทุกๆวันไหน

# %%
tsla_weekly = tsla.asfreq('W-Mon')

# %%
tsla_weekly
# Out:
#                   High         Low  ...      Volume   Adj Close
# Date                                ...
# 2016-01-04   46.276001   43.799999  ...  34135500.0   44.681999
# 2016-01-11   42.889999   40.599998  ...  20457000.0   41.570000
# 2016-01-18         NaN         NaN  ...         NaN         NaN
# 2016-01-25   40.714001   39.175999  ...  13493500.0   39.276001
# 2016-02-01   39.903999   36.549999  ...  26488000.0   39.388000
# ...                ...         ...  ...         ...         ...
# 2020-11-30  607.799988  554.510010  ...  63003100.0  567.599976
# 2020-12-07  648.789978  603.049988  ...  56309700.0  641.760010
# 2020-12-14  642.750000  610.200012  ...  52040600.0  639.830017
# 2020-12-21  668.500000  646.070007  ...  58045300.0  649.859985
# 2020-12-28  681.400024  660.799988  ...  32278600.0  663.690002
#
# [261 rows x 6 columns]

# %%
tsla_monthly = tsla.resample('M').mean()

# %%
tsla_monthly
# Out:
#                   High         Low  ...        Volume   Adj Close
# Date                                ...
# 2016-01-31   41.823789   40.057473  ...  2.085453e+07   40.912421
# 2016-02-29   35.074800   32.762300  ...  3.342645e+07   33.934000
# 2016-03-31   43.991364   42.254182  ...  2.339136e+07   43.229454
# 2016-04-30   51.175429   49.248857  ...  3.226364e+07   50.191810
# 2016-05-31   44.188572   42.715619  ...  2.459702e+07   43.326762
# 2016-06-30   43.679273   42.312182  ...  2.765291e+07   42.967818
# 2016-07-31   45.126300   43.906800  ...  1.851598e+07   44.675800
# 2016-08-31   45.331826   44.405826  ...  1.354154e+07   44.746870
# 2016-09-30   41.076572   39.999238  ...  1.681712e+07   40.451238
# 2016-10-31   40.977619   39.900571  ...  2.193638e+07   40.336667
# 2016-11-30   38.509619   37.220667  ...  2.354429e+07   37.831524
# 2016-12-31   40.595429   39.512857  ...  2.095081e+07   40.110571
# 2017-01-31   48.269900   47.041400  ...  2.516990e+07   47.864100
# 2017-02-28   53.384632   51.983579  ...  3.145789e+07   52.742211
# 2017-03-31   52.229652   51.030956  ...  2.326854e+07   51.631304
# 2017-04-30   61.582000   60.064316  ...  3.077647e+07   60.951684
# 2017-05-31   64.091818   62.299546  ...  3.364689e+07   63.304818
# 2017-06-30   74.187272   71.977454  ...  4.226161e+07   73.160727
# 2017-07-31   67.071699   64.590800  ...  4.541000e+07   65.761000
# 2017-08-31   70.991044   69.181827  ...  2.976991e+07   70.175044
# 2017-09-30   72.694300   70.682000  ...  2.787818e+07   71.571400
# 2017-10-31   69.798727   68.025636  ...  2.796289e+07   68.936636
# 2017-11-30   62.907714   60.990190  ...  3.543162e+07   62.038381
# 2017-12-31   65.414300   63.737300  ...  2.747118e+07   64.568200
# 2018-01-31   68.568285   66.537333  ...  2.958845e+07   67.716666
# 2018-02-28   68.534421   66.032526  ...  2.873421e+07   67.155474
# 2018-03-31   64.645620   61.932762  ...  3.744488e+07   63.196666
# 2018-04-30   59.114190   56.531809  ...  4.531210e+07   57.954571
# 2018-05-31   58.924909   57.042818  ...  3.535866e+07   57.970455
# 2018-06-30   68.532476   65.741238  ...  5.081550e+07   67.120095
# 2018-07-31   63.642953   61.074857  ...  4.103052e+07   62.394952
# 2018-08-31   67.542869   64.639130  ...  6.029570e+07   66.242869
# 2018-09-30   59.177579   56.660000  ...  5.159879e+07   58.029579
# 2018-10-31   58.628261   55.352783  ...  6.225233e+07   56.998609
# 2018-11-30   69.963238   67.524667  ...  3.167121e+07   68.899047
# 2018-12-31   70.568736   67.242947  ...  3.853979e+07   68.821895
# 2019-01-31   64.702762   62.091905  ...  4.182193e+07   63.698857
# 2019-02-28   62.350842   60.521474  ...  3.382897e+07   61.545684
# 2019-03-31   56.545238   54.689905  ...  5.090321e+07   55.551428
# 2019-04-30   54.162667   52.463238  ...  5.493983e+07   53.331143
# 2019-05-31   44.859818   43.079000  ...  6.422700e+07   43.943091
# 2019-06-30   43.616401   41.896700  ...  5.374265e+07   42.743300
# 2019-07-31   48.997727   47.641455  ...  4.530380e+07   48.476455
# 2019-08-31   45.797000   44.331818  ...  3.040695e+07   45.020545
# 2019-09-30   48.245100   46.611700  ...  3.394382e+07   47.452300
# 2019-10-31   54.000696   52.125652  ...  4.956143e+07   53.270956
# 2019-11-30   68.515800   66.777900  ...  3.944270e+07   67.660000
# 2019-12-31   76.347524   74.202477  ...  4.930476e+07   75.538952
# 2020-01-31  107.285715  102.938000  ...  9.695679e+07  105.731809
# 2020-02-29  166.152104  153.288210  ...  1.243649e+08  159.489368
# 2020-03-31  117.411547  106.974091  ...  9.566705e+07  111.820273
# 2020-04-30  137.320382  128.212762  ...  9.082798e+07  132.719715
# 2020-05-31  163.147200  156.069100  ...  6.817590e+07  159.885102
# 2020-06-30  196.173181  187.734000  ...  5.813016e+07  192.708453
# 2020-07-31  303.024820  281.311821  ...  8.605307e+07  292.028179
# 2020-08-31  367.357906  346.349333  ...  7.416088e+07  360.059711
# 2020-09-30  428.257618  395.665713  ...  8.268023e+07  413.495239
# 2020-10-31  436.831822  421.228180  ...  3.789393e+07  427.209545
# 2020-11-30  476.083501  453.335501  ...  3.912994e+07  465.612498
# 2020-12-31  647.822726  615.457725  ...  5.437936e+07  638.818640
#
# [60 rows x 6 columns]

# %%
# pip install quandl

# %%
import quandl

# %%
quandl.ApiConfig.api_key = 'cLnhdwJG48QxnPeyijgC'

# %%
msft = quandl.get('EOD/MSFT', start_date=start, end_date=end)

# %%
msft
# Out:
#              Open     High     Low  ...    Adj_Low  Adj_Close  Adj_Volume
# Date                                ...
# 2016-01-04  54.32  54.8000  53.390  ...  48.779325  50.067560  53777963.0
# 2016-01-05  54.93  55.3900  54.540  ...  49.830013  50.295970  34079674.0
# 2016-01-06  54.32  54.4001  53.640  ...  49.007735  49.382328  39518863.0
# 2016-01-07  52.70  53.4850  52.070  ...  47.573318  47.664682  56564852.0
# 2016-01-08  52.37  53.2800  52.150  ...  47.646409  47.810865  48753969.0
# ...           ...      ...     ...  ...        ...        ...         ...
# 2017-12-21  86.05  86.1000  85.400  ...  81.940182  82.036130  17990745.0
# 2017-12-22  85.40  85.6300  84.920  ...  81.479628  82.045725  14145841.0
# 2017-12-26  85.31  85.5346  85.030  ...  81.585171  81.940182   9891237.0
# 2017-12-27  85.65  85.9800  85.215  ...  81.762676  82.237622  14678025.0
# 2017-12-28  85.90  85.9300  85.550  ...  82.084105  82.247217  10594344.0
#
# [502 rows x 12 columns]

# %%
# data = quandl.get_table('WIKI/PRICES', ticker = 'AAPL',
#                         qopts = {'columns' : ['ticker', 'date', 'adj_close']},
#                         data = {'gte' : '2016-01-01', 'lte' : '2021-01-01'}, 
#                         paginate = True)
data = quandl.get_table('WIKI/PRICES', qopts = { 'columns': ['ticker', 'date', 'adj_close'] }, ticker = ['AAPL'], date = { 'gte': '2016-01-01', 'lte': '2021-01-01' },paginate = True)

# %%
df = data.iloc[::-1]

# %%
df
# Out:
#      ticker       date   adj_close
# None
# 559    AAPL 2016-01-04  101.783763
# 558    AAPL 2016-01-05   99.233131
# 557    AAPL 2016-01-06   97.291172
# 556    AAPL 2016-01-07   93.185040
# 555    AAPL 2016-01-08   93.677776
# ...     ...        ...         ...
# 4      AAPL 2018-03-21  171.270000
# 3      AAPL 2018-03-22  168.845000
# 2      AAPL 2018-03-23  164.940000
# 1      AAPL 2018-03-26  172.770000
# 0      AAPL 2018-03-27  168.340000
#
# [560 rows x 3 columns]

# %% [markdown]
# ## Import from Google Drive

# %% [markdown]
# มาถึงส่วนที่ใช้กันจริง และคู่ควรกว่าตัวอื่นๆ นั่นก็คือ Google Drive เพราะไม่เปลืองพื้นที่คอม โดยตัวข้อมูลจะเป็นข้อมูลที่เราคัดสรรมาแล้วก่อนที่จะเอามาเก็บไว้ แต่ข้อแม้คือใช้ได้แค่ใน Colab นะ

# %% [markdown]
# ตัวใช้ Code ชุดนี้เพื่อเข้าถึง Drive ก่อน ซึ่งมันต้องเป็น Drive ของเจ้าของเท่านั้น เนื่องจากต้องมีการใส่รหัสเพื่อเข้าถึงข้อมูล

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# หลังจากที่กด run แล้วจะได้รูปนี้ออกมา

# %% [markdown]
# ![drive.PNG](data:image/png;base64,...)

# %% [markdown]
# สุดท้ายก็ต้องไปหา File Path เพื่อที่จะรู้ว่าข้อมูลอยู่ตรงไหนของ Drive หรือ Folder ไหน

# %% [markdown]
# ![d.PNG](data:image/png;base64,...)

# %%
# path = "/content/drive/MyDrive/File/Oil.csv"
path = "/content/drive/MyDrive/Colab Notebooks/data/Oil.csv"

# %%
import pandas as pd
df = pd.read_csv(path)

# %%
df
# Out:
#            Date       Open       High  ...      Close  Adj Close    Volume
# 0     11/4/2016  39.720001  40.750000  ...  40.360001  40.360001  679351.0
# 1     12/4/2016  40.349998  42.250000  ...  42.169998  42.169998  796837.0
# 2     13/4/2016  41.630001  42.419998  ...  41.759998  41.759998  730437.0
# 3     14/4/2016  41.540001  42.160000  ...  41.500000  41.500000  488614.0
# 4     15/4/2016  41.430000  41.730000  ...  40.360001  40.360001  520146.0
# ...         ...        ...        ...  ...        ...        ...       ...
# 1252   2/4/2021  61.450001  61.450001  ...  61.450001  61.450001  605567.0
# 1253   5/4/2021  61.500000  61.500000  ...  58.650002  58.650002  438864.0
# 1254   6/4/2021  58.799999  60.900002  ...  59.330002  59.330002  457348.0
# 1255   7/4/2021  59.259998  60.040001  ...  59.770000  59.770000  475537.0
# 1256   8/4/2021  59.520000  59.930000  ...  59.599998  59.599998  475537.0
#
# [1257 rows x 7 columns]

# %% [markdown]
# #Import csv

# %% [markdown]
# ดาวน์โหลดไฟล์ CSV : https://drive.google.com/file/d/1IiX3YRXFqmxjfei2w0RFnUwWkoTQrVXI/view?usp=sharing

# %% [markdown]
# ในการทำงานจริง อย่าลืม จัด folder data ด้วยนะครับ เพื่อความง่ายในตอนนี้ ใส่ data และ python notebook ไว้ folder เดียวกันได้ครับ
#
# ส่วนในการเรียนนี้ ใช้ colab ก็มี 3 วิธีในการนำไฟล์มาวางใน colab ด้วยกัน
# https://www.roelpeters.be/how-to-uploading-files-in-google-colab/

# %% [markdown]
# part นี้ แนะนำ ไปทำใน python ธรรมดานะครับ โดยการจัดใส่ folder กันไปก่อน เพราะการทำงานจริงเราไม่ทำกันใน colab ครับ

# %%
import pandas as pd

# %% [markdown]
# read csv กันธรรมดาๆ แต่สำหรับใครที่ยังไม่เคยใช้อย่าลืม import pandas ลงเครื่องกันก่อน

# %%
oil = pd.read_csv(path)

# %% [markdown]
# Load เสร็จก็มาเช็คไฟล์ทั้งรวม อาจจะเพิ่มหัว ท้ายไป .head(), .tail() ถ้าอยากดูกี่ Row ก็ใส่ จำนวนลงไปในวงเล็บได้เลยนะครับ

# %%
oil
# Out:
#            Date       Open       High  ...      Close  Adj Close    Volume
# 0     11/4/2016  39.720001  40.750000  ...  40.360001  40.360001  679351.0
# 1     12/4/2016  40.349998  42.250000  ...  42.169998  42.169998  796837.0
# 2     13/4/2016  41.630001  42.419998  ...  41.759998  41.759998  730437.0
# 3     14/4/2016  41.540001  42.160000  ...  41.500000  41.500000  488614.0
# 4     15/4/2016  41.430000  41.730000  ...  40.360001  40.360001  520146.0
# ...         ...        ...        ...  ...        ...        ...       ...
# 1252   2/4/2021  61.450001  61.450001  ...  61.450001  61.450001  605567.0
# 1253   5/4/2021  61.500000  61.500000  ...  58.650002  58.650002  438864.0
# 1254   6/4/2021  58.799999  60.900002  ...  59.330002  59.330002  457348.0
# 1255   7/4/2021  59.259998  60.040001  ...  59.770000  59.770000  475537.0
# 1256   8/4/2021  59.520000  59.930000  ...  59.599998  59.599998  475537.0
#
# [1257 rows x 7 columns]

# %% [markdown]
# เช็ค Types กันคร่าวๆก่อน เผื่อบางที่อาจจะมีบาง Type แปลกพอไปจัดการต่ออาจมีปัญหา

# %%
oil.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object

# %% [markdown]
# ### Tips

# %% [markdown]
# รู้หรือไม่ เราสามารถ set index column ได้นะ ตั้งแต่ตอน import หรือหลัง import มาแล้วก็ได้ ตัว index จะทำให้เราทำงานได้สะดวกขึ้น

# %%
oil = pd.read_csv(path, index_col='Date')

# %%
oil = read_csv('Oil.csv')
oil = oil.set_index('Date')

# %% [markdown]
# ## Import Excel

# %% [markdown]
# ดาวน์โหลดไฟล์ excel : https://drive.google.com/file/d/1wDxrf2R0LF2zIiaH5TePisLBJAR6Fq4i/view?usp=sharing

# %%
excel_oil =  '/content/drive/MyDrive/Colab Notebooks/data/Oil.xlsx'
oil_xlsx = pd.read_excel(excel_oil)

# %% [markdown]
# เช็คข้อมูลปกติ หรือจะเช็คหัว,ท้ายแบบ csv ก็ได้ตามใจชอบ

# %%
oil_xlsx
# Out:
#            Date       Open       High  ...      Close  Adj Close    Volume
# 0    2016-04-11  39.720001  40.750000  ...  40.360001  40.360001  679351.0
# 1    2016-04-12  40.349998  42.250000  ...  42.169998  42.169998  796837.0
# 2    2016-04-13  41.630001  42.419998  ...  41.759998  41.759998  730437.0
# 3    2016-04-14  41.540001  42.160000  ...  41.500000  41.500000  488614.0
# 4    2016-04-15  41.430000  41.730000  ...  40.360001  40.360001  520146.0
# ...         ...        ...        ...  ...        ...        ...       ...
# 1252 2021-04-02  61.450001  61.450001  ...  61.450001  61.450001  605567.0
# 1253 2021-04-05  61.500000  61.500000  ...  58.650002  58.650002  438864.0
# 1254 2021-04-06  58.799999  60.900002  ...  59.330002  59.330002  457348.0
# 1255 2021-04-07  59.259998  60.040001  ...  59.770000  59.770000  475537.0
# 1256 2021-04-08  59.520000  59.930000  ...  59.599998  59.599998  475537.0
#
# [1257 rows x 7 columns]

# %% [markdown]
# ###Tips

# %% [markdown]
# ความสนุกเริ่มขึ้นที่ตรงนี้ ปกติหากเราต้องการเก็บข้อมูล Excel ไว้ในเครื่อง งานหนึ่งงานมันคงไม่ได้มีแค่ Sheet เดียว ดังนั้นเราสามารถเลือก Sheet ที่ Load ได้ด้วยนะ

# %%
oil_xlsx = pd.read_excel(excel_oil, sheet_name=['CVX'])
oil_xlsx
# Out:
# {'CVX':            Date        Open        High  ...       Close   Adj Close   Volume
#  0    2016-04-11   96.870003   97.300003  ...   95.239998   76.680489  6644200
#  1    2016-04-12   95.690002   97.940002  ...   97.510002   78.508133  8783400
#  2    2016-04-13   97.800003   97.910004  ...   97.599998   78.580582  6406800
#  3    2016-04-14   97.650002   98.269997  ...   97.980003   78.886536  6162200
#  4    2016-04-15   97.709999   97.800003  ...   97.230003   78.282684  6551600
#  ...         ...         ...         ...  ...         ...         ...      ...
#  1253 2021-04-01  105.260002  105.860001  ...  105.750000  105.750000  8514700
#  1254 2021-04-05  105.730003  105.830002  ...  104.510002  104.510002  8692700
#  1255 2021-04-06  104.250000  105.080002  ...  103.580002  103.580002  8125100
#  1256 2021-04-07  103.470001  104.570000  ...  104.190002  104.190002  7699300
#  1257 2021-04-08  103.519997  103.620003  ...  103.019997  103.019997  8283000
#
#  [1258 rows x 7 columns]}

# %% [markdown]
# หรือจะ Load มาทั้งสอง Sheet เลยก็ได้

# %%
oil_xlsx = pd.read_excel(excel_oil, sheet_name=['Oil','CVX'])
oil_xlsx
# Out:
# {'CVX':            Date        Open        High  ...       Close   Adj Close   Volume
#  0    2016-04-11   96.870003   97.300003  ...   95.239998   76.680489  6644200
#  1    2016-04-12   95.690002   97.940002  ...   97.510002   78.508133  8783400
#  2    2016-04-13   97.800003   97.910004  ...   97.599998   78.580582  6406800
#  3    2016-04-14   97.650002   98.269997  ...   97.980003   78.886536  6162200
#  4    2016-04-15   97.709999   97.800003  ...   97.230003   78.282684  6551600
#  ...         ...         ...         ...  ...         ...         ...      ...
#  1253 2021-04-01  105.260002  105.860001  ...  105.750000  105.750000  8514700
#  1254 2021-04-05  105.730003  105.830002  ...  104.510002  104.510002  8692700
#  1255 2021-04-06  104.250000  105.080002  ...  103.580002  103.580002  8125100
#  1256 2021-04-07  103.470001  104.570000  ...  104.190002  104.190002  7699300
#  1257 2021-04-08  103.519997  103.620003  ...  103.019997  103.019997  8283000
#
#  [1258 rows x 7 columns],
#  'Oil':            Date       Open       High  ...      Close  Adj Close    Volume
#  0    2016-04-11  39.720001  40.750000  ...  40.360001  40.360001  679351.0
#  1    2016-04-12  40.349998  42.250000  ...  42.169998  42.169998  796837.0
#  2    2016-04-13  41.630001  42.419998  ...  41.759998  41.759998  730437.0
#  3    2016-04-14  41.540001  42.160000  ...  41.500000  41.500000  488614.0
#  4    2016-04-15  41.430000  41.730000  ...  40.360001  40.360001  520146.0
#  ...         ...        ...        ...  ...        ...        ...       ...
#  1252 2021-04-02  61.450001  61.450001  ...  61.450001  61.450001  605567.0
#  1253 2021-04-05  61.500000  61.500000  ...  58.650002  58.650002  438864.0
#  1254 2021-04-06  58.799999  60.900002  ...  59.330002  59.330002  457348.0
#  1255 2021-04-07  59.259998  60.040001  ...  59.770000  59.770000  475537.0
#  1256 2021-04-08  59.520000  59.930000  ...  59.599998  59.599998  475537.0
#
#  [1257 rows x 7 columns]}

# %% [markdown]
# คราวนี้เลือกเลยจะเอาอันไหนนนน

# %%
oil_xlsx['Oil']
# Out:
#            Date       Open       High  ...      Close  Adj Close    Volume
# 0    2016-04-11  39.720001  40.750000  ...  40.360001  40.360001  679351.0
# 1    2016-04-12  40.349998  42.250000  ...  42.169998  42.169998  796837.0
# 2    2016-04-13  41.630001  42.419998  ...  41.759998  41.759998  730437.0
# 3    2016-04-14  41.540001  42.160000  ...  41.500000  41.500000  488614.0
# 4    2016-04-15  41.430000  41.730000  ...  40.360001  40.360001  520146.0
# ...         ...        ...        ...  ...        ...        ...       ...
# 1252 2021-04-02  61.450001  61.450001  ...  61.450001  61.450001  605567.0
# 1253 2021-04-05  61.500000  61.500000  ...  58.650002  58.650002  438864.0
# 1254 2021-04-06  58.799999  60.900002  ...  59.330002  59.330002  457348.0
# 1255 2021-04-07  59.259998  60.040001  ...  59.770000  59.770000  475537.0
# 1256 2021-04-08  59.520000  59.930000  ...  59.599998  59.599998  475537.0
#
# [1257 rows x 7 columns]

# %%
oil_xlsx['CVX']
# Out:
#            Date        Open        High  ...       Close   Adj Close   Volume
# 0    2016-04-11   96.870003   97.300003  ...   95.239998   76.680489  6644200
# 1    2016-04-12   95.690002   97.940002  ...   97.510002   78.508133  8783400
# 2    2016-04-13   97.800003   97.910004  ...   97.599998   78.580582  6406800
# 3    2016-04-14   97.650002   98.269997  ...   97.980003   78.886536  6162200
# 4    2016-04-15   97.709999   97.800003  ...   97.230003   78.282684  6551600
# ...         ...         ...         ...  ...         ...         ...      ...
# 1253 2021-04-01  105.260002  105.860001  ...  105.750000  105.750000  8514700
# 1254 2021-04-05  105.730003  105.830002  ...  104.510002  104.510002  8692700
# 1255 2021-04-06  104.250000  105.080002  ...  103.580002  103.580002  8125100
# 1256 2021-04-07  103.470001  104.570000  ...  104.190002  104.190002  7699300
# 1257 2021-04-08  103.519997  103.620003  ...  103.019997  103.019997  8283000
#
# [1258 rows x 7 columns]

# %% [markdown]
# #Yfinance - คำเตือน เค้าเลิกกันแล้วเหมือนกัน นี่เพื่อกรณีศึกษา

# %% [markdown]
# อันนี้ค่อนข้างเก่านิดนึง แล้วก็ไม่ค่อยมีคนใช้กันแล้ว แต่มันมีสิ่งที่น่าสนใจอยู่

# %%
# pip install yfinance

# %%
import yfinance as yf
tickerSymbol = 'NFLX'

# %%
tickerData = yf.Ticker(tickerSymbol)

# %% [markdown]
# ดึงค่าเหมือนเดิม แต่อันนี้กำหนด Period ได้เลย

# %%
tickerDf = tickerData.history(period='1d', start=start, end=end)

# %%
tickerDf
# Out:
#                   Open        High  ...  Dividends  Stock Splits
# Date                                ...
# 2016-01-04  109.000000  110.000000  ...          0             0
# 2016-01-05  110.449997  110.580002  ...          0             0
# 2016-01-06  105.290001  117.910004  ...          0             0
# 2016-01-07  116.360001  122.180000  ...          0             0
# 2016-01-08  116.330002  117.720001  ...          0             0
# ...                ...         ...  ...        ...           ...
# 2020-12-24  515.119995  519.349976  ...          0             0
# 2020-12-28  516.429993  523.659973  ...          0             0
# 2020-12-29  519.900024  536.549988  ...          0             0
# 2020-12-30  530.130005  533.260010  ...          0             0
# 2020-12-31  525.530029  545.500000  ...          0             0
#
# [1259 rows x 7 columns]

# %% [markdown]
# ### Tips

# %% [markdown]
# สิ่งที่ชอบคืนอันนี้เพราะมี Earning Date ให้ดูจะได้รู้ว่างบของหุ้นตัวที่สนใจจะประกาศวันไหนแถมมี recommendations ให้ด้วยนะ

# %%
tickerData.calendar
# Out:
#                                     0                    1
# Earnings Date     2021-07-14 00:00:00  2021-07-19 00:00:00
# Earnings Average                 3.07                 3.07
# Earnings Low                     2.35                 2.35
# Earnings High                    3.21                 3.21
# Revenue Average            7337140000           7337140000
# Revenue Low                7273590000           7273590000
# Revenue High               7753850000           7753850000

# %%
tickerData.recommendations
# Out:
#                                   Firm      To Grade  From Grade Action
# Date
# 2012-04-24 07:05:00  Canaccord Genuity          Sell               main
# 2012-04-24 07:22:00      Goldman Sachs       Neutral               main
# 2012-04-24 10:14:00          Dougherty       Neutral               main
# 2012-05-31 06:33:00       Bank oferica  Underperform               main
# 2012-07-25 05:32:00       PiperJaffray       Neutral  Overweight   down
# ...                                ...           ...         ...    ...
# 2021-04-21 12:55:46     Morgan Stanley    Overweight               main
# 2021-04-21 13:56:30      Deutsche Bank           Buy               main
# 2021-04-21 14:25:05            Wedbush  Underperform               main
# 2021-04-21 14:42:25  Canaccord Genuity           Buy               main
# 2021-04-21 14:45:30        Cowen & Co.    Outperform               main
#
# [468 rows x 4 columns]
